# %%
#https://docs.ribbon.finance/faq/dov-trading-and-options --APY and fees
GNOISIS_AUCTION = "0x0b7fFc1f4AD541A4Ed16b40D8c37f0929158D101"
SWAP_CONTRACT = "0xEb8CAB2F4663247db8eAfb556F498c861bB4e161"
RIBBON_EARN_VAULT = "0x84c2b16fa6877a8ff4f3271db7ea837233dfd6f0"
RIBBON_TOKEN = "0x6123B0049F904d730dB3C36a31167D9d4121fA6B"
VOTING_ESCROW = "0x19854C9A5fFa8116f48f984bDF946fB9CEa9B5f7"
TOKEN_MINTER = "0x5B0655F938A72052c46d2e94D206ccB6FF625A3A"
RIBBON_LEND_VAULT = "0xa3A369bED8bDa02de33B8Af5aeF8aFa6fAb8E593"
GAUGE_CONTROLLER = "0x0cb9cc35cEFa5622E8d25aF36dD56DE142eF6415"

# %%
#Ethereum Vaults
ethCallVault = "0x0fabaf48bbf864a3947bdd0ba9d764791a60467a"
ethCallVaultV2 = "0x25751853Eab4D0eB3652B5eB6ecB102A2789644B"
wbtcCallVault = "0x8b5876f5B0Bf64056A89Aa7e97511644758c3E8c"
wbtcCallVaultV2 = "0x65a833afDc250D9d38f8CD9bC2B1E3132dB13B2F"
usdcETHPutVault = "0x16772a7f4a3ca291C21B8AcE76F9332dDFfbb5Ef"
yvUSDCETHPutVault = "0x8FE74471F198E426e96bE65f40EeD1F8BA96e54f"
yvUSDCETHPutVaultV2 = "0xCc323557c71C0D1D20a1861Dc69c06C5f3cC9624"
aaveCallVault = "0xe63151A0Ed4e5fafdc951D877102cf0977Abd365"
stETHCallVault = "0x53773E034d9784153471813dacAFF53dBBB78E8c"
apeCallVault = "0xc0cF10Dd710aefb209D9dc67bc746510ffd98A53"
rethCallVault = "0xA1Da0580FA96129E753D736a5901C31Df5eC5edf"

#Avalanche Vaults
avaxCallVault = "0x98d03125c62DaE2328D9d3cb32b7B969e6a87787"
savaxCallVault = "0x6BF686d99A4cE17798C45d09C21181fAc29A9fb3"
usdcAvaxPutVault = "0x9DD6be071b4292cc88B8190aB718329adEA3E3a3"

#Treasury Vaults
perpCallVault = "0xe44eDF7aD1D434Afe3397687DD0A914674F2E405"
balCallVault = "0x2a6B048eB15C7d4ddCa27db4f9A454196898A0Fe"
spellCallVault = "0x42cf874bBe5564EfCF252bC90829551f4ec639DC"
badgerCallVault = "0x270F4a26a3fE5766CcEF9608718491bb057Be238"

#Pausers
pauserEth = "0xE04e8Ae290965AD4F7E40c68041c493d2e89cDC3"
pauserAvax = "0xf08d6a9c2C5a2Dc9B8645c5Ac0b529D4046D19aa"

#Ribbon Earn vaults
rearnUSDC = "0x84c2b16FA6877a8fF4F3271db7ea837233DFd6f0"

#Ethereum Assets
weth = "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"
wbtc = "0x2260fac5e5542a773aa44fbcfedf7c193bc2c599"
usdc = "0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48"
aave = "0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9"
perp = "0xbC396689893D065F41bc2C6EcbeE5e0085233447"
ape = "0x4d224452801ACEd8B2F0aebE155379bb5D594381"
bal = "0xba100000625a3754423978a60c9317c58a424e3D"
reth = "0xae78736Cd615f374D3085123A210448E74Fc6393"
steth = "0xae7ab96520de3a18e5e111b5eaab095312d7fe84"
spell = "0x090185f2135308BaD17527004364eBcC2D37e5F6"
badger = "0x3472A5A71965499acd81997a54BBA8D852C6E53d"

#Avalanche Assets
wavax = "0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7"
savax = "0x2b2C81e08f1Af8835a78Bb2A90AE924ACE0eA4bE"
usdce = "0xA7D7079b0FEaD91F3e65f86E8915Cb59c1a4C664"

STAKING_V1 = "0xd46f9546ebAbAAC44DC1B6D0Ac1eeb357D34FBeB"

# %%
import json
from web3 import Web3
from collections import defaultdict
from web3.middleware import geth_poa_middleware

# %%
w3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/0290160ac7b5492d89913bba7746b772'))

w3.middleware_onion.inject(geth_poa_middleware,layer=0)
print(f'Connected: {w3.isConnected()}')
# Out:
# Connected: True

# %%
def create_contract(address,abi):
    return w3.eth.contract(
        address = w3.toChecksumAddress(address),
        abi= json.load(open(abi,'r'))
    )

def readValue(fn_call, block_identifier='latest', default_value=None,debug=False):
    try:
        return fn_call.call(block_identifier = block_identifier)
    except Exception as E:
        if  debug:
            print(E)
        return default_value

def getEvents(abi):
    abi=json.loads(abi)
    events=[]

    for i in abi:
        if i.get('type') == 'event' :
            events.append(i)
    return events

def getFunctions(abi):
    abi=json.loads(abi)
    functions=[]

    for i in abi:
        if i.get('stateMutability') == 'view':
            functions.append(i)
    return functions

# %%
gauge_controller_contract = create_contract(GAUGE_CONTROLLER,'./abi/gauge_controller.json')
GAUGES = []
idx = 0
while(True):
    gauge = readValue(gauge_controller_contract.functions.gauges(idx),default_value = "0x0000000000000000000000000000000000000000")
    idx = idx + 1
    if(gauge == "0x0000000000000000000000000000000000000000"):
        break
    GAUGES.append(gauge)

print(GAUGES)
# Out:
# ['0xa8A9699161f266f7E79080ca0b65210820BE8732', '0x98c371567b8A196518dcb4A4383387A2C7339382', '0x4e079dCA26A4fE2586928c1319b20b1bf9f9be72', '0x9038403C3F7C6B5Ca361C82448DAa48780D7C8Bd', '0x8913EAb16a302dE3E498BbA39940e7A55c0B9325', '0x4bA4Afa8071b0a9FE3097700cdadE02DD0e16fd0', '0x9674126Ff31e5EcE36De0CF03A49351a7C814587', '0x0000000000000000000000000000000000000001']

# %%
def getGaugeData(gaugeAddress):

    gauge_contract = create_contract(gaugeAddress,'./abi/gauge.json')
    name = readValue(gauge_contract.functions.name(),default_value = "")
    symbol = readValue(gauge_contract.functions.symbol(),default_value = "")
    decimals = readValue(gauge_contract.functions.decimals(),default_value = 0)
    lp_token = readValue(gauge_contract.functions.lp_token(),default_value = "")
    total_supply = readValue(gauge_contract.functions.totalSupply(),default_value = 0)
    working_supply = readValue(gauge_contract.functions.working_supply(),default_value = 0)
    inflation_rate = readValue(gauge_contract.functions.inflation_rate(),default_value = 0)
    reward_count = readValue(gauge_contract.functions.reward_count(),default_value = 0)
    reward_tokens = []
    reward_data = []
    
    print(f'Gauge Address: {gaugeAddress}\nName: {name}\nSymbol: {symbol}\nDecimals: {decimals}\nLpToken: {lp_token}\nTotal Supply: {total_supply}\nWorking Supply: {working_supply}\nInflastion Rate: {inflation_rate}\nReward Count: {reward_count}')

    i = 0
    while (True):
        reward_token = readValue(gauge_contract.functions.reward_tokens(i),default_value = "0x0000000000000000000000000000000000000000")
        i = i + 1
        if (reward_token == "0x0000000000000000000000000000000000000000"):
            break
        reward_token_data = readValue(gauge_contract.functions.reward_data(reward_token),default_value = {})
        print(f'Reward Token: {reward_token} --> \nToken Data: {reward_token_data}')
    print("\n---------------------------------------------------------------------------------------")

# %%
for gauge in GAUGES:
    getGaugeData(gauge)
# Out:
# Gauge Address: 0xa8A9699161f266f7E79080ca0b65210820BE8732
# Name: Ribbon.fi ryvUSDC-ETH-P-THETA Gauge Deposit
# Symbol: ryvUSDC-ETH-P-THETA-gauge
# Decimals: 18
# LpToken: 0xCc323557c71C0D1D20a1861Dc69c06C5f3cC9624
# Total Supply: 9220350699476
# Working Supply: 3969621121835
# Inflastion Rate: 413359788359788359
# Reward Count: 0
#
# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-fe455851c194> in <module>
#       1 for gauge in GAUGES:
# ----> 2     getGaugeData(gauge)
#       3
#
# <ipython-input-28-4806cfe5d5df> in getGaugeData(gaugeAddress)
#       7     lp_token = readValue(gauge_contract.functions.lp_token(),default_value = "")
#       8     total_supply = readValue(gauge_contract.functions.totalSupply(),default_value = 0)
# ----> 9     working_supply = readValue(gauge_contract.functions.working_supply(),default_value = 0)
#      10     inflation_rate = readValue(gauge_contract.functions.inflation_rate(),default_value = 0)
#      11     reward_count = readValue(gauge_contract.functions.reward_count(),default_value = 0)
#
# <ipython-input-26-83c57f9adcd4> in readValue(fn_call, block_identifier, default_value, debug)
#       7 def readValue(fn_call, block_identifier='latest', default_value=None,debug=False):
#       8     try:
# ----> 9         return fn_call.call(block_identifier = block_identifier)
#      10     except Exception as E:
#      11         if  debug:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/contract.py in call(self, transaction, block_identifier, state_override)
#     968         block_id = parse_block_identifier(self.web3, block_identifier)
#     969
# --> 970         return call_contract_function(
#     971             self.web3,
#     972             self.address,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/contract.py in call_contract_function(web3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, *args, **kwargs)
#    1523     )
#    1524
# -> 1525     return_data = web3.eth.call(
#    1526         call_transaction,
#    1527         block_identifier=block_id,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/module.py in caller(*args, **kwargs)
#      55             return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56         result_formatters, error_formatters, null_result_formatters = response_formatters
# ---> 57         result = w3.manager.request_blocking(method_str,
#      58                                              params,
#      59                                              error_formatters,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/manager.py in request_blocking(self, method, params, error_formatters, null_result_formatters)
#     195         Make a synchronous request using the provider
#     196         """
# --> 197         response = self._make_request(method, params)
#     198         return self.formatted_response(response,
#     199                                        params,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/manager.py in _make_request(self, method, params)
#     148             self.middleware_onion)
#     149         self.logger.debug("Making request. Method: %s", method)
# --> 150         return request_func(method, params)
#     151
#     152     async def _coro_make_request(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/gas_price_strategy.py in middleware(method, params)
#      88             )
#      89             return make_request(method, (transaction,))
# ---> 90         return make_request(method, params)
#      91
#      92     return middleware
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/attrdict.py in middleware(method, params)
#      31     """
#      32     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 33         response = make_request(method, params)
#      34
#      35         if 'result' in response:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/buffered_gas_estimate.py in middleware(method, params)
#      38                 )
#      39                 return make_request(method, [transaction])
# ---> 40         return make_request(method, params)
#      41     return middleware
#      42
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/middleware/exception_retry_request.py in middleware(method, params)
#     103             for i in range(retries):
#     104                 try:
# --> 105                     return make_request(method, params)
#     106                 # https://github.com/python/mypy/issues/5349
#     107                 except errors:  # type: ignore
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/providers/rpc.py in make_request(self, method, params)
#      86                           self.endpoint_uri, method)
#      87         request_data = self.encode_rpc_request(method, params)
# ---> 88         raw_response = make_post_request(
#      89             self.endpoint_uri,
#      90             request_data,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/web3/_utils/request.py in make_post_request(endpoint_uri, data, *args, **kwargs)
#     100     session = _get_session(endpoint_uri)
#     101     # https://github.com/python/mypy/issues/2582
# --> 102     response = session.post(endpoint_uri, data=data, *args, **kwargs)  # type: ignore
#     103     response.raise_for_status()
#     104
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     588         """
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#     592     def put(self, url, data=None, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in getresponse(self)
#    1343         try:
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#    1347                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def getEventsFromAbi(abi):
    data = json.load(open(abi,'r'))
    
    for i in data:
        if(i["type"] == "event"):
            print(i["name"])
            if(i["inputs"] != None):
                for j in i["inputs"]:
                    print(f'Name: {j["name"]} Type: {j["type"]}')
            print("----------------------------------------------------------")

# %%
getEventsFromAbi('./abi/vault.json')
# Out:
# Approval
# Name: owner Type: address
# Name: spender Type: address
# Name: value Type: uint256
# ----------------------------------------------------------
# AuctionDurationSet
# Name: auctionDuration Type: uint256
# Name: newAuctionDuration Type: uint256
# ----------------------------------------------------------
# CapSet
# Name: oldCap Type: uint256
# Name: newCap Type: uint256
# ----------------------------------------------------------
# CloseShort
# Name: options Type: address
# Name: withdrawAmount Type: uint256
# Name: manager Type: address
# ----------------------------------------------------------
# CollectVaultFees
# Name: performanceFee Type: uint256
# Name: vaultFee Type: uint256
# Name: round Type: uint256
# Name: feeRecipient Type: address
# ----------------------------------------------------------
# Deposit
# Name: account Type: address
# Name: amount Type: uint256
# Name: round Type: uint256
# ----------------------------------------------------------
# InitiateWithdraw
# Name: account Type: address
# Name: shares Type: uint256
# Name: round Type: uint256
# ----------------------------------------------------------
# InstantWithdraw
# Name: account Type: address
# Name: amount Type: uint256
# Name: round Type: uint256
# ----------------------------------------------------------
# ManagementFeeSet
# Name: managementFee Type: uint256
# Name: newManagementFee Type: uint256
# ----------------------------------------------------------
# NewOffer
# Name: swapId Type: uint256
# Name: seller Type: address
# Name: oToken Type: address
# Name: biddingToken Type: address
# Name: minPrice Type: uint256
# Name: minBidSize Type: uint256
# Name: totalSize Type: uint256
# ----------------------------------------------------------
# NewOptionStrikeSelected
# Name: strikePrice Type: uint256
# Name: delta Type: uint256
# ----------------------------------------------------------
# OpenShort
# Name: options Type: address
# Name: depositAmount Type: uint256
# Name: manager Type: address
# ----------------------------------------------------------
# OwnershipTransferred
# Name: previousOwner Type: address
# Name: newOwner Type: address
# ----------------------------------------------------------
# PerformanceFeeSet
# Name: performanceFee Type: uint256
# Name: newPerformanceFee Type: uint256
# ----------------------------------------------------------
# Redeem
# Name: account Type: address
# Name: share Type: uint256
# Name: round Type: uint256
# ----------------------------------------------------------
# Transfer
# Name: from Type: address
# Name: to Type: address
# Name: value Type: uint256
# ----------------------------------------------------------
# Withdraw
# Name: account Type: address
# Name: amount Type: uint256
# Name: shares Type: uint256
# ----------------------------------------------------------

# %%
def getFunctionsFromAbi(abi):
    data = json.load(open(abi,'r'))
    count = 0
    for i in data:
        if(i["type"] == "function" and i["stateMutability"] == "view"):
            count = count +1
            print(f'{count} {i["name"]}')
            
            for j in i["outputs"]:
                if len(i["outputs"]) <= 1:
                    print(f'Name : {i["name"]}  Type: {j["type"]}')
                else :
                    print(f'Name : {j["name"]}  Type: {j["type"]}')
                

            print("----------------------------------------------------------")

# %%
getFunctionsFromAbi('./abi/vault.json')
# Out:
# 1 DELAY
# Name : DELAY  Type: uint256
# ----------------------------------------------------------
# 2 GAMMA_CONTROLLER
# Name : GAMMA_CONTROLLER  Type: address
# ----------------------------------------------------------
# 3 MARGIN_POOL
# Name : MARGIN_POOL  Type: address
# ----------------------------------------------------------
# 4 OTOKEN_FACTORY
# Name : OTOKEN_FACTORY  Type: address
# ----------------------------------------------------------
# 5 PERIOD
# Name : PERIOD  Type: uint256
# ----------------------------------------------------------
# 6 SWAP_CONTRACT
# Name : SWAP_CONTRACT  Type: address
# ----------------------------------------------------------
# 7 USDC
# Name : USDC  Type: address
# ----------------------------------------------------------
# 8 WETH
# Name : WETH  Type: address
# ----------------------------------------------------------
# 9 accountVaultBalance
# Name : accountVaultBalance  Type: uint256
# ----------------------------------------------------------
# 10 allowance
# Name : allowance  Type: uint256
# ----------------------------------------------------------
# 11 auctionDuration
# Name : auctionDuration  Type: uint256
# ----------------------------------------------------------
# 12 balanceOf
# Name : balanceOf  Type: uint256
# ----------------------------------------------------------
# 13 cap
# Name : cap  Type: uint256
# ----------------------------------------------------------
# 14 currentOption
# Name : currentOption  Type: address
# ----------------------------------------------------------
# 15 currentOtokenPremium
# Name : currentOtokenPremium  Type: uint256
# ----------------------------------------------------------
# 16 currentQueuedWithdrawShares
# Name : currentQueuedWithdrawShares  Type: uint256
# ----------------------------------------------------------
# 17 decimals
# Name : decimals  Type: uint8
# ----------------------------------------------------------
# 18 depositReceipts
# Name : round  Type: uint16
# Name : amount  Type: uint104
# Name : unredeemedShares  Type: uint128
# ----------------------------------------------------------
# 19 feeRecipient
# Name : feeRecipient  Type: address
# ----------------------------------------------------------
# 20 keeper
# Name : keeper  Type: address
# ----------------------------------------------------------
# 21 lastQueuedWithdrawAmount
# Name : lastQueuedWithdrawAmount  Type: uint256
# ----------------------------------------------------------
# 22 lastStrikeOverrideRound
# Name : lastStrikeOverrideRound  Type: uint16
# ----------------------------------------------------------
# 23 liquidityGauge
# Name : liquidityGauge  Type: address
# ----------------------------------------------------------
# 24 managementFee
# Name : managementFee  Type: uint256
# ----------------------------------------------------------
# 25 name
# Name : name  Type: string
# ----------------------------------------------------------
# 26 nextOption
# Name : nextOption  Type: address
# ----------------------------------------------------------
# 27 nextOptionReadyAt
# Name : nextOptionReadyAt  Type: uint256
# ----------------------------------------------------------
# 28 optionAuctionID
# Name : optionAuctionID  Type: uint256
# ----------------------------------------------------------
# 29 optionState
# Name : nextOption  Type: address
# Name : currentOption  Type: address
# Name : nextOptionReadyAt  Type: uint32
# ----------------------------------------------------------
# 30 optionsPremiumPricer
# Name : optionsPremiumPricer  Type: address
# ----------------------------------------------------------
# 31 optionsPurchaseQueue
# Name : optionsPurchaseQueue  Type: address
# ----------------------------------------------------------
# 32 overriddenStrikePrice
# Name : overriddenStrikePrice  Type: uint256
# ----------------------------------------------------------
# 33 owner
# Name : owner  Type: address
# ----------------------------------------------------------
# 34 performanceFee
# Name : performanceFee  Type: uint256
# ----------------------------------------------------------
# 35 premiumDiscount
# Name : premiumDiscount  Type: uint256
# ----------------------------------------------------------
# 36 pricePerShare
# Name : pricePerShare  Type: uint256
# ----------------------------------------------------------
# 37 roundPricePerShare
# Name : roundPricePerShare  Type: uint256
# ----------------------------------------------------------
# 38 shareBalances
# Name : heldByAccount  Type: uint256
# Name : heldByVault  Type: uint256
# ----------------------------------------------------------
# 39 shares
# Name : shares  Type: uint256
# ----------------------------------------------------------
# 40 strikeSelection
# Name : strikeSelection  Type: address
# ----------------------------------------------------------
# 41 symbol
# Name : symbol  Type: string
# ----------------------------------------------------------
# 42 totalBalance
# Name : totalBalance  Type: uint256
# ----------------------------------------------------------
# 43 totalPending
# Name : totalPending  Type: uint256
# ----------------------------------------------------------
# 44 totalSupply
# Name : totalSupply  Type: uint256
# ----------------------------------------------------------
# 45 vaultParams
# Name : isPut  Type: bool
# Name : decimals  Type: uint8
# Name : asset  Type: address
# Name : underlying  Type: address
# Name : minimumSupply  Type: uint56
# Name : cap  Type: uint104
# ----------------------------------------------------------
# 46 vaultPauser
# Name : vaultPauser  Type: address
# ----------------------------------------------------------
# 47 vaultState
# Name : round  Type: uint16
# Name : lockedAmount  Type: uint104
# Name : lastLockedAmount  Type: uint104
# Name : totalPending  Type: uint128
# Name : queuedWithdrawShares  Type: uint128
# ----------------------------------------------------------
# 48 withdrawals
# Name : round  Type: uint16
# Name : shares  Type: uint128
# ----------------------------------------------------------

# %%
def get_underlying_token_price_from_options_pricer(vault_address):
    vault_contract = create_contract(vault_address,"./abi/vault.json")

    current_option = readValue(vault_contract.functions.currentOption(),default_value="0x0000000000000000000000000000000000000000")
    print(current_option)
    options_premium_pricer_address = readValue(vault_contract.functions.optionsPremiumPricer(),default_value="0x0000000000000000000000000000000000000000")
    print(options_premium_pricer_address)
    option_contract= create_contract(current_option,"./abi/oToken.json")
    options_premium_pricer_contract = create_contract(options_premium_pricer_address,"./abi/options_pricer.json")
    option_decimals = readValue(option_contract.functions.decimals(),default_value=8)
    print(option_decimals)
    underlying_token_price_usd = readValue(options_premium_pricer_contract.functions.getUnderlyingPrice(),0)
    print(underlying_token_price_usd)

# %%
get_underlying_token_price_from_options_pricer("0x25751853Eab4D0eB3652B5eB6ecB102A2789644B")
# Out:
# 0xA649E5c1458c9CE6ACd7652b5F0D345A67ab639c
# 0x5bA2A42b74A72a1A3ccC37CF03802a0b7A551139
# 8
# None
